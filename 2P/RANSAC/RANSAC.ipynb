# %%
import cv2
import numpy as np
from stich import *
import matplotlib.pyplot as plt

# %%
img2 = cv2.imread('Ejemplo/zv/3.jpg')
img1 = cv2.imread('Ejemplo/zv/4.jpg')

# %%
kp1, des1 = detect_compute_sift(img1)
kp2, des2 = detect_compute_sift(img2)

# %%
matches = get_matches(des1,des2)

# %%
matches[0].trainIdx
matches[0].queryIdx
# Out:
# 1184

# %%
pts1 = np.float32([kp1[matches[i].queryIdx] for i in range(len(matches))])
pts2 = np.float32([kp2[matches[i].trainIdx] for i in range(len(matches))])

# %%
(H, status) = cv2.findHomography(pts1, pts2, cv2.RANSAC,4)

# %%
result = cv2.warpPerspective(img1, H,(img1.shape[1] + img2.shape[1], img1.shape[0]))
result[0:img2.shape[0], 0:img2.shape[1]] = img2

# %%
plt.figure(figsize = (20,20))
resultado = cv2.cvtColor(result,cv2.COLOR_BGR2RGB)
resultado=resultado[ 0:1900, 0:4000 ]
plt.imshow(resultado)

# %%
resultado = cv2.cvtColor(resultado,cv2.COLOR_RGB2BGR)
img1 = resultado
img2 = cv2.imread('Ejemplo/zv/2.jpg')

# %%
kp1, des1 = detect_compute_sift(img1)
kp2, des2 = detect_compute_sift(img2)

# %%
matches = get_matches(des1,des2)

# %%
matches[0].trainIdx
matches[0].queryIdx
# Out:
# 175

# %%
pts1 = np.float32([kp1[matches[i].queryIdx] for i in range(len(matches))])
pts2 = np.float32([kp2[matches[i].trainIdx] for i in range(len(matches))])

# %%
(H, status) = cv2.findHomography(pts1, pts2, cv2.RANSAC,4)

# %%
result = cv2.warpPerspective(img1, H,(img1.shape[1] + img2.shape[1], img1.shape[0] + img2.shape[0] ))
result[0:img2.shape[0], 0:img2.shape[1]] = img2

# %%
plt.figure(figsize = (20,20))
resultado = cv2.cvtColor(result,cv2.COLOR_BGR2RGB)
resultado=resultado[ 0:2400, 0:9000 ]
plt.imshow(resultado)
