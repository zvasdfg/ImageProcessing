# %% [markdown]
# # Espacios de color

# %% [markdown]
# <img src = "Colores.png" width = 600/>

# %% [markdown]
# ## RGB

# %% [markdown]
# red (700.0nm wavelength), green (546.1nm), and blue (435.8nm)

# %% [markdown]
# <img src = "cubo_rgb.jpg" width = 400/>

# %% [markdown]
# <img src = "cat.jpeg" width = 800/>

# %% [markdown]
# ## Leer imágenes (installar pillow)

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("cat.jpeg")

# %%
print(type(img))
img.shape
# Out:
# <class 'numpy.ndarray'>
# (800, 1200, 3)

# %%
plt.figure(figsize=(10,10))
plt.imshow(img)

# %% [markdown]
# ## opencv

# %%
import cv2

# %%
img = cv2.imread("cat.jpeg")

# %%
img.shape
# Out:
# (800, 1200, 3)

# %%
plt.figure(figsize=(10,10))
plt.imshow(img)

# %%
plt.figure(figsize=(10,10))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
import numpy as np
img2 = np.zeros(img.shape,dtype = int)

img2[:,:,0]  = img[:,:,2]
img2[:,:,1]  = img[:,:,1]
img2[:,:,2]  = img[:,:,0]
plt.imshow(img2)

# %%
img = cv2.imread('rubik.png')

# %%
plt.figure(figsize=(8,8))
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
B = img[:,:,0]
G = img[:,:,1]
R = img[:,:,2]

# %%
plt.figure(figsize=(8,8))
plt.imshow(B,cmap= 'gray')

# %%
plt.figure(figsize=(8,8))
plt.imshow(G,cmap= 'gray')

# %%
plt.figure(figsize=(8,8))
plt.imshow(R,cmap= 'gray')

# %%
plt.figure(figsize=(8,8))
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2GRAY),cmap ='gray')

# %% [markdown]
# ## RGBA

# %%
cat = cv2.imread("cat.jpeg")
rubik = cv2.imread('rubik.png')
print(cat.shape)
print(rubik.shape)

# %% [markdown]
# ## YUV
#
# Usado en los sistemas PAL y NTSC de difusión de televisión
#
# Y = Luminancia
#
# U y V = Crominancia

# %% [markdown]
# <img src = "YUV.png" />

# %% [markdown]
# <img src = "YUV_ecuaciones.png" width = 600/>

# %% [markdown]
# <img src = "yuv_space.png" width =600/>

# %%
cv2.cvtColor(img,cv2.COLOR_BGR2YUV_I420 )

# %% [markdown]
# ## Otros espacios de colores: CIELAB, XYZ, LUV

# %% [markdown]
# # Formatos de imagen

# %% [markdown]
# # Bitmap, JPEG, TIFF, PNG

# %% [markdown]
# <img src = '1bit.png' />
# <img src = '2bit.png' />
# <img src = '4bit.png' />
# <img src = '16bit.png' />
# <img src = '16paleta.png' />
